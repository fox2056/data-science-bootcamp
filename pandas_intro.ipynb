# %% [markdown]
# <a href="https://colab.research.google.com/github/fox2056/data-science-bootcamp/blob/main/pandas_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=[12, 12, 12])
df
# Out:
#     0
# 0  12
# 1  12
# 2  12

# %%
df = pd.DataFrame(data=[12, 12, 12], index = ['first', 'second', 'third'], columns=['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# third      12

# %%
df = pd.DataFrame(data={'WIG20':['PKN ORLEN', 'PKP PKO'],
                        'mWIG40': ['Amica', 'Playway']})
df
# Out:
#        WIG20   mWIG40
# 0  PKN ORLEN    Amica
# 1    PKP PKO  Playway

# %%
df = pd.DataFrame(data=[[10, 12, 13],[23, 12, 10]], index = ['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.index
# Out:
# Index(['first', 'second'], dtype='object')

# %%
df.values
# Out:
# array([[10, 12, 13],
#        [23, 12, 10]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, first to second
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   2 non-null      int64
#  1   col_2   2 non-null      int64
#  2   col_3   2 non-null      int64
# dtypes: int64(3)
# memory usage: 172.0+ bytes

# %%
df.describe().T
# Out:
#        count  mean       std   min    25%   50%    75%   max
# col_1    2.0  16.5  9.192388  10.0  13.25  16.5  19.75  23.0
# col_2    2.0  12.0  0.000000  12.0  12.00  12.0  12.00  12.0
# col_3    2.0  11.5  2.121320  10.0  10.75  11.5  12.25  13.0

# %%
df['col_1']
# Out:
# first     10
# second    23
# Name: col_1, dtype: int64

# %%
df[['col_1']]
# Out:
#         col_1
# first      10
# second     23

# %%
type(df[['col_1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns = ['a', 'b', 'c']

# %%
df
# Out:
#          a   b   c
# first   10  12  13
# second  23  12  10

# %%
df.a
# Out:
# first     10
# second    23
# Name: a, dtype: int64

# %%
df.columns = ['a', 'sprzedaz_grudzien', 'c']

# %%
df.sprzedaz_grudzien
# Out:
# first     12
# second    12
# Name: sprzedaz_grudzien, dtype: int64

# %%
df['d'] = df.a + df.c

# %%
df
# Out:
#          a  sprzedaz_grudzien   c   d
# first   10                 12  13  23
# second  23                 12  10  33

# %%
df.loc['second']
# Out:
# a                    23
# sprzedaz_grudzien    12
# c                    10
# d                    33
# Name: second, dtype: int64

# %%
df.iloc[1]
# Out:
# a                    23
# sprzedaz_grudzien    12
# c                    10
# d                    33
# Name: second, dtype: int64

# %%
df.loc['second', 'c']
# Out:
# np.int64(10)

# %%
df.loc[:, 'c']
# Out:
# first     13
# second    10
# Name: c, dtype: int64
